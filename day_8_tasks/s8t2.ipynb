# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d akshaydattatraykhare/diabetes-dataset

# %%
# !unzip /content/diabetes-dataset.zip -d /content/

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv('diabetes.csv')
dataset
